# %% [markdown]
# # Question B1 (15 marks)
#
# Real world datasets often have a mix of numeric and categorical features – this dataset is one example. To build models on such data, categorical features have to be encoded or embedded.
#
# PyTorch Tabular is a library that makes it very convenient to build neural networks for tabular data. It is built on top of PyTorch Lightning, which abstracts away boilerplate model training code and makes it easy to integrate other tools, e.g. TensorBoard for experiment tracking.
#
# For questions B1 and B2, the following features should be used:
# - **Numeric / Continuous** features: dist_to_nearest_stn, dist_to_dhoby, degree_centrality, eigenvector_centrality, remaining_lease_years, floor_area_sqm
# - **Categorical** features: month, town, flat_model_type, storey_range

# %% [markdown]
# ---

# %%
# !pip install pytorch_tabular[extra]
# Out:
# Requirement already satisfied: pytorch_tabular[extra] in c:\users\admin\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (2.4.0)
# Requirement already satisfied: numpy>1.20.0 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.0 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (1.4.2)
# Requirement already satisfied: pytorch-lightning<2.2.0,>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (2.1.4)
# Requirement already satisfied: omegaconf>=2.3.0 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (2.3.0)
# Requirement already satisfied: torchmetrics<1.3.0,>=0.10.0 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (1.2.1)
# Requirement already satisfied: tensorboard!=2.5.0,>2.2.0 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (2.18.0)
# Requirement already satisfied: protobuf<4.26.0,>=3.20.0 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (3.20.3)
# Requirement already satisfied: pytorch-tabnet==4.1 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (4.1.0)
# Requirement already satisfied: PyYAML<6.1.0,>=5.4 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (6.0.1)
# Requirement already satisfied: matplotlib>3.1 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (3.8.4)
# Requirement already satisfied: ipywidgets in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (7.8.1)
# Requirement already satisfied: einops<0.8.0,>=0.6.0 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (0.7.0)
# Requirement already satisfied: rich>=11.0.0 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (13.3.5)
# Requirement already satisfied: wandb<0.17.0,>=0.15.0 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (0.16.6)
# Requirement already satisfied: plotly<5.19.0,>=5.13.0 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (5.18.0)
# Requirement already satisfied: kaleido<0.3.0,>=0.2.0 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (0.2.1)
# Requirement already satisfied: captum<0.8.0,>=0.5.0 in c:\users\admin\anaconda3\lib\site-packages (from pytorch_tabular[extra]) (0.7.0)
# Requirement already satisfied: scipy>1.4 in c:\users\admin\anaconda3\lib\site-packages (from pytorch-tabnet==4.1->pytorch_tabular[extra]) (1.13.1)
# Requirement already satisfied: tqdm>=4.36 in c:\users\admin\anaconda3\lib\site-packages (from pytorch-tabnet==4.1->pytorch_tabular[extra]) (4.66.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from matplotlib>3.1->pytorch_tabular[extra]) (2.9.0.post0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\admin\anaconda3\lib\site-packages (from omegaconf>=2.3.0->pytorch_tabular[extra]) (4.9.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.1.5->pytorch_tabular[extra]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.1.5->pytorch_tabular[extra]) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\admin\anaconda3\lib\site-packages (from plotly<5.19.0,>=5.13.0->pytorch_tabular[extra]) (8.2.2)
# Requirement already satisfied: fsspec>=2022.5.0 in c:\users\admin\anaconda3\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (2024.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\admin\anaconda3\lib\site-packages (from pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (4.11.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in c:\users\admin\anaconda3\lib\site-packages (from pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (0.11.7)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\admin\anaconda3\lib\site-packages (from rich>=11.0.0->pytorch_tabular[extra]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from rich>=11.0.0->pytorch_tabular[extra]) (2.18.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn>=1.3.0->pytorch_tabular[extra]) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn>=1.3.0->pytorch_tabular[extra]) (2.2.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (1.66.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (3.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (69.5.1)
# Requirement already satisfied: six>1.9 in c:\users\admin\appdata\roaming\python\python312\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (3.0.3)
# Requirement already satisfied: filelock in c:\users\admin\anaconda3\lib\site-packages (from torch>=1.11.0->pytorch_tabular[extra]) (3.13.1)
# Requirement already satisfied: sympy in c:\users\admin\anaconda3\lib\site-packages (from torch>=1.11.0->pytorch_tabular[extra]) (1.12)
# Requirement already satisfied: networkx in c:\users\admin\anaconda3\lib\site-packages (from torch>=1.11.0->pytorch_tabular[extra]) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\lib\site-packages (from torch>=1.11.0->pytorch_tabular[extra]) (3.1.4)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in c:\users\admin\anaconda3\lib\site-packages (from wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (3.1.37)
# Requirement already satisfied: requests<3,>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (2.32.2)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (6.0.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (2.16.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (0.4.0)
# Requirement already satisfied: setproctitle in c:\users\admin\anaconda3\lib\site-packages (from wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (1.3.3)
# Requirement already satisfied: appdirs>=1.4.3 in c:\users\admin\anaconda3\lib\site-packages (from wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (1.4.4)
# Requirement already satisfied: comm>=0.1.3 in c:\users\admin\appdata\roaming\python\python312\site-packages (from ipywidgets->pytorch_tabular[extra]) (0.2.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\admin\anaconda3\lib\site-packages (from ipywidgets->pytorch_tabular[extra]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from ipywidgets->pytorch_tabular[extra]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\admin\anaconda3\lib\site-packages (from ipywidgets->pytorch_tabular[extra]) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from ipywidgets->pytorch_tabular[extra]) (8.26.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from ipywidgets->pytorch_tabular[extra]) (1.0.0)
# Requirement already satisfied: colorama in c:\users\admin\appdata\roaming\python\python312\site-packages (from Click!=8.0.0,>=7.1->wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (0.4.6)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\admin\anaconda3\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (3.9.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\admin\anaconda3\lib\site-packages (from GitPython!=3.1.29,>=1.0.0->wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (4.0.7)
# Requirement already satisfied: decorator in c:\users\admin\appdata\roaming\python\python312\site-packages (from ipython>=4.0.0->ipywidgets->pytorch_tabular[extra]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin\appdata\roaming\python\python312\site-packages (from ipython>=4.0.0->ipywidgets->pytorch_tabular[extra]) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\admin\appdata\roaming\python\python312\site-packages (from ipython>=4.0.0->ipywidgets->pytorch_tabular[extra]) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\admin\appdata\roaming\python\python312\site-packages (from ipython>=4.0.0->ipywidgets->pytorch_tabular[extra]) (3.0.47)
# Requirement already satisfied: stack-data in c:\users\admin\appdata\roaming\python\python312\site-packages (from ipython>=4.0.0->ipywidgets->pytorch_tabular[extra]) (0.6.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=11.0.0->pytorch_tabular[extra]) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.0.0->wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\admin\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard!=2.5.0,>2.2.0->pytorch_tabular[extra]) (2.1.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\admin\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (7.0.8)
# Requirement already satisfied: mpmath>=0.19 in c:\users\admin\anaconda3\lib\site-packages (from sympy->torch>=1.11.0->pytorch_tabular[extra]) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.2.0,>=2.0.0->pytorch_tabular[extra]) (1.9.3)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\admin\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb<0.17.0,>=0.15.0->pytorch_tabular[extra]) (4.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\admin\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->pytorch_tabular[extra]) (0.8.4)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\admin\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\admin\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\admin\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\admin\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (6.4.1)
# Requirement already satisfied: wcwidth in c:\users\admin\appdata\roaming\python\python312\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets->pytorch_tabular[extra]) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=4.0.0->ipywidgets->pytorch_tabular[extra]) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=4.0.0->ipywidgets->pytorch_tabular[extra]) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\admin\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=4.0.0->ipywidgets->pytorch_tabular[extra]) (0.2.3)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\admin\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\admin\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (7.10.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (5.9.2)
# Requirement already satisfied: overrides>=5.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\admin\appdata\roaming\python\python312\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (2.0.4)
# Requirement already satisfied: ipykernel in c:\users\admin\appdata\roaming\python\python312\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\admin\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (4.19.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\admin\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\admin\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\admin\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\users\admin\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (306)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (2.0.7)
# Requirement already satisfied: rfc3339-validator in c:\users\admin\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\admin\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\admin\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\admin\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (2.16.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\admin\appdata\roaming\python\python312\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (1.8.5)
# Requirement already satisfied: nest-asyncio in c:\users\admin\appdata\roaming\python\python312\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (1.6.0)
# Requirement already satisfied: webencodings in c:\users\admin\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\admin\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\admin\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (2.1)
# Requirement already satisfied: uri-template in c:\users\admin\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (2.5)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\admin\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->pytorch_tabular[extra]) (1.2.3)

# %%
SEED = 42

import os

import random
random.seed(SEED)

import numpy as np
np.random.seed(SEED)

import pandas as pd

from pytorch_tabular import TabularModel
from pytorch_tabular.models import CategoryEmbeddingModelConfig
from pytorch_tabular.config import (
    DataConfig,
    OptimizerConfig,
    TrainerConfig,
)

# %% [markdown]
# 1.Divide the dataset (‘hdb_price_prediction.csv’) into train, validation and test sets by using entries from year 2019 and before as training data, year 2020 as validation data and year 2021 as test data.
# **Do not** use data from year 2022 and year 2023.

# %%
df = pd.read_csv('hdb_price_prediction.csv')

# Training Data Set: Year 2019 and before
df_train = df[df['year'] <= 2019].copy()
# Validation Data Set: Year 2020
df_val = df[df['year'] == 2020].copy()
# Testing Data Set: Year 2021
df_test = df[df['year'] == 2021].copy()

# Dropping Columns not used for training
df_train.drop(columns=['year','full_address','nearest_stn'], inplace=True)
df_val.drop(columns=['year','full_address','nearest_stn'], inplace=True)
df_test.drop(columns=['year','full_address','nearest_stn'], inplace=True)

print("Training Data:", df_train.shape)
print("Validation Data:", df_val.shape)
print("Testing Data:", df_test.shape)
# Out:
# Training Data: (64057, 11)
# Validation Data: (23313, 11)
# Testing Data: (29057, 11)

# %% [markdown]
# 2.Refer to the documentation of **PyTorch Tabular** and perform the following tasks: https://pytorch-tabular.readthedocs.io/en/latest/#usage
# - Use **[DataConfig](https://pytorch-tabular.readthedocs.io/en/latest/data/)** to define the target variable, as well as the names of the continuous and categorical variables.
# - Use **[TrainerConfig](https://pytorch-tabular.readthedocs.io/en/latest/training/)** to automatically tune the learning rate. Set batch_size to be 1024 and set max_epoch as 50.
# - Use **[CategoryEmbeddingModelConfig](https://pytorch-tabular.readthedocs.io/en/latest/models/#category-embedding-model)** to create a feedforward neural network with 1 hidden layer containing 50 neurons.
# - Use **[OptimizerConfig](https://pytorch-tabular.readthedocs.io/en/latest/optimizer/)** to choose Adam optimiser. There is no need to set the learning rate (since it will be tuned automatically) nor scheduler.
# - Use **[TabularModel](https://pytorch-tabular.readthedocs.io/en/latest/tabular_model/)** to initialise the model and put all the configs together.

# %%
numeric = ['dist_to_nearest_stn','dist_to_dhoby','degree_centrality','eigenvector_centrality', 
           'remaining_lease_years','floor_area_sqm']
categorical = ['month','town','flat_model_type','storey_range']

data_config = DataConfig(
    target=["resale_price"],  
    continuous_cols=numeric,
    categorical_cols=categorical,
)

# %%
trainer_config = TrainerConfig(
    auto_lr_find=True,  # automatically tune the learning rate
    batch_size=1024,
    max_epochs=50,
)

# %%
model_config = CategoryEmbeddingModelConfig(
    task="regression",
    layers="50",  
)

# %%
optimizer_config = OptimizerConfig(optimizer='Adam')

# %%
tabular_model = TabularModel(
    data_config=data_config,
    model_config=model_config,
    optimizer_config=optimizer_config,
    trainer_config=trainer_config,
)
# Out:
# 2024-10-09 13:03:35,093 - {pytorch_tabular.tabular_model:140} - INFO - Experiment Tracking is turned off

# %% [markdown]
# 3.Report the test RMSE error and the test R2 value that you obtained.

# %%
from torch_optimizer import QHAdam
# Training Tabular Model
tabular_model.fit(df_train, 
                  validation=df_val,
                  optimizer=QHAdam)
# Out:
# Epoch 4/49 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63/63 0:00:01 • 0:00:00 41.33it/s v_num: 5.000 train_loss:
#                                                                                 2630292992.000 valid_loss:
#                                                                                 2961529856.000
#                                                                                 valid_mean_squared_error:
#                                                                                 2961529856.000
#                                                                                 train_mean_squared_error:
#                                                                                 2438466304.000
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 2024-10-09 13:03:48,805 - {pytorch_tabular.tabular_model:663} - INFO - Training the model completed
# 2024-10-09 13:03:48,807 - {pytorch_tabular.tabular_model:1489} - INFO - Loading the best model
# C:\Users\Admin\anaconda3\envs\myenv_py38\lib\site-packages\pytorch_tabular\utils\python_utils.py:84: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=map_location)

# %%
# Evaluation and Prediction
evaluation = tabular_model.evaluate(df_test)
predicted = tabular_model.predict(df_test)
# Out:
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29/29 0:00:00 • 0:00:00 49.73it/s
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_loss         │       6465972736.0        │
# │  test_mean_squared_error  │       6465972736.0        │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# True Values and Predicted Values
y_true = df_test['resale_price'].values
y_pred = predicted['resale_price_prediction']

mse = mean_squared_error(y_true, y_pred)
print("Root Mean Squared Error (RMSE):", np.sqrt(mse))
r2 = r2_score(y_true, y_pred)
print("R2 Score:", r2)
# Out:
# Root Mean Squared Error (RMSE): 80411.27126542194
# R2 Score: 0.7555578453226205

# %% [markdown]
# 4.Print out the corresponding rows in the dataframe for the top 25 test samples with the largest errors. Identify a trend in these poor predictions and suggest a way to reduce these errors.

# %%
# Create absolute error column
df_test['absolute_error'] = abs(y_true - y_pred)

# Top 25 with largest error
worst_predictions = df.nlargest(25, 'absolute_error')
worst_predictions = worst_predictions.reset_index(drop=True)

worst_predictions
# Out:
#     month  year         town                full_address   nearest_stn  \
# 0      11  2021  BUKIT MERAH            46 SENG POH ROAD   Tiong Bahru
# 1       2  2021   QUEENSTOWN            46 STIRLING ROAD  Commonwealth
# 2      12  2021   QUEENSTOWN              89 DAWSON ROAD    Queenstown
# 3       8  2021   QUEENSTOWN            42 STIRLING ROAD    Queenstown
# 4      10  2021   QUEENSTOWN              92 DAWSON ROAD    Queenstown
# 5       6  2021   QUEENSTOWN              91 DAWSON ROAD    Queenstown
# 6       6  2021   QUEENSTOWN              89 DAWSON ROAD    Queenstown
# 7      11  2021  BUKIT MERAH          127D KIM TIAN ROAD   Tiong Bahru
# 8       6  2021   QUEENSTOWN         150 MEI LING STREET    Queenstown
# 9       6  2021   QUEENSTOWN              91 DAWSON ROAD    Queenstown
# 10      3  2021   QUEENSTOWN              90 DAWSON ROAD    Queenstown
# 11     10  2021  BUKIT MERAH            56 HAVELOCK ROAD   Tiong Bahru
# 12      6  2021  BUKIT BATOK  288A BUKIT BATOK STREET 25   Bukit Batok
# 13      8  2021   ANG MO KIO    310A ANG MO KIO AVENUE 1    Ang Mo Kio
# 14     12  2021   QUEENSTOWN              92 DAWSON ROAD    Queenstown
# 15      9  2021   QUEENSTOWN              90 DAWSON ROAD    Queenstown
# 16      9  2021  BUKIT MERAH          96A HENDERSON ROAD   Tiong Bahru
# 17     12  2021     TAMPINES      156 TAMPINES STREET 12      Tampines
# 18     10  2021    WOODLANDS     805 WOODLANDS STREET 81     Woodlands
# 19      9  2021   QUEENSTOWN              91 DAWSON ROAD    Queenstown
# 20     12  2021   QUEENSTOWN              89 DAWSON ROAD    Queenstown
# 21     12  2021  BUKIT MERAH            49 KIM PONG ROAD   Tiong Bahru
# 22      4  2021   QUEENSTOWN              92 DAWSON ROAD    Queenstown
# 23      4  2021   QUEENSTOWN              91 DAWSON ROAD    Queenstown
# 24      7  2021   QUEENSTOWN              91 DAWSON ROAD    Queenstown
#
#     dist_to_nearest_stn  dist_to_dhoby  degree_centrality  \
# 0              0.581977       2.309477           0.016807
# 1              0.570988       4.922054           0.016807
# 2              0.658035       3.807573           0.016807
# 3              0.554599       4.841933           0.016807
# 4              0.584731       3.882019           0.016807
# 5              0.745596       3.720593           0.016807
# 6              0.658035       3.807573           0.016807
# 7              0.686789       2.664024           0.016807
# 8              0.245207       4.709043           0.016807
# 9              0.745596       3.720593           0.016807
# 10             0.701852       3.763948           0.016807
# 11             0.451387       2.128424           0.016807
# 12             1.292540      10.763777           0.016807
# 13             0.860056       7.263401           0.016807
# 14             0.584731       3.882019           0.016807
# 15             0.701852       3.763948           0.016807
# 16             0.586629       2.932814           0.016807
# 17             0.370873      12.479752           0.033613
# 18             0.419275      16.945885           0.016807
# 19             0.745596       3.720593           0.016807
# 20             0.658035       3.807573           0.016807
# 21             0.468378       2.365532           0.016807
# 22             0.584731       3.882019           0.016807
# 23             0.745596       3.720593           0.016807
# 24             0.745596       3.720593           0.016807
#
#     eigenvector_centrality                 flat_model_type  \
# 0                 0.047782                3 ROOM, Standard
# 1                 0.005350                 4 ROOM, Terrace
# 2                 0.008342  4 ROOM, Premium Apartment Loft
# 3                 0.008342                 4 ROOM, Terrace
# 4                 0.008342  4 ROOM, Premium Apartment Loft
# 5                 0.008342  4 ROOM, Premium Apartment Loft
# 6                 0.008342  4 ROOM, Premium Apartment Loft
# 7                 0.047782                5 ROOM, Improved
# 8                 0.008342            EXECUTIVE, Apartment
# 9                 0.008342  4 ROOM, Premium Apartment Loft
# 10                0.008342  4 ROOM, Premium Apartment Loft
# 11                0.047782                5 ROOM, Improved
# 12                0.000217            EXECUTIVE, Apartment
# 13                0.006243                5 ROOM, Improved
# 14                0.008342  4 ROOM, Premium Apartment Loft
# 15                0.008342  4 ROOM, Premium Apartment Loft
# 16                0.047782                5 ROOM, Improved
# 17                0.000229           EXECUTIVE, Maisonette
# 18                0.000024            EXECUTIVE, Apartment
# 19                0.008342  4 ROOM, Premium Apartment Loft
# 20                0.008342  4 ROOM, Premium Apartment Loft
# 21                0.047782                3 ROOM, Standard
# 22                0.008342  4 ROOM, Premium Apartment Loft
# 23                0.008342  4 ROOM, Premium Apartment Loft
# 24                0.008342  4 ROOM, Premium Apartment Loft
#
#     remaining_lease_years  floor_area_sqm storey_range  resale_price  \
# 0               50.166667            88.0     01 TO 03      780000.0
# 1               46.916667           134.0     01 TO 03      975000.0
# 2               93.333333           109.0     04 TO 06      968000.0
# 3               46.416667           120.0     01 TO 03      930000.0
# 4               93.500000            97.0     13 TO 15      958000.0
# 5               93.916667            97.0     07 TO 09      930000.0
# 6               93.916667           109.0     10 TO 12      950000.0
# 7               90.333333           113.0     16 TO 18     1165000.0
# 8               73.416667           148.0     10 TO 12     1235000.0
# 9               93.916667           109.0     31 TO 33     1032888.0
# 10              94.166667            95.0     10 TO 12      920000.0
# 11              90.750000           114.0     34 TO 36     1245000.0
# 12              75.583333           144.0     10 TO 12      968000.0
# 13              90.166667           121.0     28 TO 30     1100000.0
# 14              93.333333            97.0     16 TO 18      938888.0
# 15              93.583333            97.0     10 TO 12      900000.0
# 16              96.750000           113.0     28 TO 30     1220000.0
# 17              61.750000           148.0     01 TO 03      998000.0
# 18              71.250000           189.0     04 TO 06      980000.0
# 19              93.666667            97.0     25 TO 27      968800.0
# 20              93.416667            97.0     19 TO 21      950000.0
# 21              50.166667            88.0     01 TO 03      695000.0
# 22              94.083333            97.0     16 TO 18      928000.0
# 23              94.083333            97.0     07 TO 09      878000.0
# 24              93.833333            97.0     34 TO 36      988000.0
#
#     absolute_error
# 0      419085.3750
# 1      413788.3125
# 2      407555.0625
# 3      394128.4375
# 4      383422.9375
# 5      380730.5625
# 6      366701.5625
# 7      365478.0000
# 8      365216.5625
# 9      362622.0625
# 10     361855.4375
# 11     353463.3125
# 12     349168.5625
# 13     347867.0625
# 14     342816.9375
# 15     340919.0000
# 16     338185.6250
# 17     331031.6875
# 18     329963.3125
# 19     329933.4375
# 20     329738.9375
# 21     329711.1875
# 22     329617.8750
# 23     327753.0625
# 24     327142.3125

# %%
# Analysis of numeric data
print("\nAnalysis of Worst Predictions:")
for col in ['floor_area_sqm', 'remaining_lease_years', 'dist_to_nearest_stn', 'dist_to_dhoby', 
            'degree_centrality', 'eigenvector_centrality']:
    print(f"\n{col} statistics:")
    print(f"Mean for worst predictions: {worst_predictions[col].mean():.2f}")
    print(f"Mean for all test data: {df_test[col].mean():.2f}")

# Analysis of categorical data
for col in ['month', 'town', 'flat_model_type', 'storey_range']:
    print(f"\nTop 5 {col} in worst predictions:")
    print(worst_predictions[col].value_counts().nlargest(5))
    
    # Compare to overall distribution
    print(f"\nOverall top 5 {col} distribution:")
    print(df_test[col].value_counts().nlargest(5))
# Out:
# Analysis of Worst Predictions:
#
# floor_area_sqm statistics:
# Mean for worst predictions: 112.60
# Mean for all test data: 98.25
#
# remaining_lease_years statistics:
# Mean for worst predictions: 82.50
# Mean for all test data: 75.37
#
# dist_to_nearest_stn statistics:
# Mean for worst predictions: 0.64
# Mean for all test data: 0.82
#
# dist_to_dhoby statistics:
# Mean for worst predictions: 4.94
# Mean for all test data: 10.98
#
# degree_centrality statistics:
# Mean for worst predictions: 0.02
# Mean for all test data: 0.02
#
# eigenvector_centrality statistics:
# Mean for worst predictions: 0.02
# Mean for all test data: 0.01
#
# Top 5 month in worst predictions:
# month
# 12    5
# 6     5
# 10    3
# 9     3
# 11    2
# Name: count, dtype: int64
#
# Overall top 5 month distribution:
# month
# 8     2735
# 7     2655
# 11    2566
# 9     2510
# 10    2495
# Name: count, dtype: int64
#
# Top 5 town in worst predictions:
# town
# QUEENSTOWN     16
# BUKIT MERAH     5
# BUKIT BATOK     1
# ANG MO KIO      1
# TAMPINES        1
# Name: count, dtype: int64
#
# Overall top 5 town distribution:
# town
# SENGKANG     2749
# PUNGGOL      2735
# TAMPINES     2148
# YISHUN       1748
# WOODLANDS    1635
# Name: count, dtype: int64
#
# Top 5 flat_model_type in worst predictions:
# flat_model_type
# 4 ROOM, Premium Apartment Loft    13
# 5 ROOM, Improved                   4
# EXECUTIVE, Apartment               3
# 3 ROOM, Standard                   2
# 4 ROOM, Terrace                    2
# Name: count, dtype: int64
#
# Overall top 5 flat_model_type distribution:
# flat_model_type
# 4 ROOM, Model A              7416
# 5 ROOM, Improved             5286
# 3 ROOM, New Generation       1961
# 4 ROOM, Premium Apartment    1959
# 3 ROOM, Model A              1725
# Name: count, dtype: int64
#
# Top 5 storey_range in worst predictions:
# storey_range
# 01 TO 03    5
# 10 TO 12    5
# 16 TO 18    3
# 04 TO 06    2
# 07 TO 09    2
# Name: count, dtype: int64
#
# Overall top 5 storey_range distribution:
# storey_range
# 04 TO 06    6615
# 07 TO 09    5927
# 10 TO 12    5284
# 01 TO 03    5002
# 13 TO 15    2958
# Name: count, dtype: int64

# %% [markdown]
# Trends:
# 1. Worst predictions are dominated by "4 ROOM, Premium Apartment Loft" (13 out of 25 cases), even though this flat model type is not in the top 5 in the test data.
# 2. 16 out of 25 worst predictions are in Queenstown, and Queenstown is not in the top 5 towns.
#
# Ways to reduce errors:
# 1. Premium, unique properties are not predicted well, possibly due to flat model type being relatively rare. More training data on premium properties can help the model learn better. Inclusion of more specific flat features can provide more grounds for comparison between premium and common flat types, so model can justify and predict prices better for premium flats.
# 2. Location-specific pricing in Queenstown is not well captured, hence the model needs more training data from Queenstown.
